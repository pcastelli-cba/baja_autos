# %% [markdown]
# <a href="https://colab.research.google.com/github/pcastelli-cba/baja_autos/blob/main/Desafio1_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Leyendo archivos para generar dataset

# %% [markdown]
# Importar archivos de registro automotor

# %%
import pandas as pd
#anios = ['2018','2019','2020','2021','2022']
anios = ['2020','2021','2022']
meses = ['01','02','03','04','05','06','07','08','09','10','11','12']

def listado(anios,meses):
  lista=[]
  for a in range(len(anios)):
    for m in range(len(meses)):
      anio=anios[a]
      mes=meses[m]
      print("Comprobando datos de Año : "+str(anios[a])+" Mes : "+str(meses[m]))
      try :
        url = 'https://raw.githubusercontent.com/pcastelli-cba/baja_autos/main/dnrpa-bajas-autos-'+str(anio)+str(mes)+'.csv'
        df = pd.read_csv(url, index_col=0)
        lista.append(url)
      except : 
        print("Datos inexistentes para el Año : "+str(anios[a])+" Mes : "+str(meses[m]))
        break
  return lista

dataFrame = pd.concat(map(pd.read_csv, listado(anios,meses)), ignore_index=True)
print(dataFrame)

dataFrame.to_csv('archivo unificado.csv')
# Out:
# Comprobando datos de Año : 2020 Mes : 01
# Comprobando datos de Año : 2020 Mes : 02
# Comprobando datos de Año : 2020 Mes : 03
# Comprobando datos de Año : 2020 Mes : 04
# Comprobando datos de Año : 2020 Mes : 05
# Comprobando datos de Año : 2020 Mes : 06
# Comprobando datos de Año : 2020 Mes : 07
# Comprobando datos de Año : 2020 Mes : 08
# Comprobando datos de Año : 2020 Mes : 09
# Comprobando datos de Año : 2020 Mes : 10
# Comprobando datos de Año : 2020 Mes : 11
# Comprobando datos de Año : 2020 Mes : 12
# Comprobando datos de Año : 2021 Mes : 01
# Comprobando datos de Año : 2021 Mes : 02
# Comprobando datos de Año : 2021 Mes : 03
# Comprobando datos de Año : 2021 Mes : 04
# Comprobando datos de Año : 2021 Mes : 05
# Comprobando datos de Año : 2021 Mes : 06
# Comprobando datos de Año : 2021 Mes : 07
# Comprobando datos de Año : 2021 Mes : 08
# Comprobando datos de Año : 2021 Mes : 09
# Comprobando datos de Año : 2021 Mes : 10
# Comprobando datos de Año : 2021 Mes : 11
# Comprobando datos de Año : 2021 Mes : 12
# Comprobando datos de Año : 2022 Mes : 01
# Datos inexistentes para el Año : 2022 Mes : 01
#                                     tramite_tipo tramite_fecha  \
# 0        AUTOMOTOR - BAJA P/DEST/SIN/DESG/ENVEJ.    2020-01-22
# 1      AUTOMOTOR - BAJA C/RECUPERACION DE PIEZAS    2020-01-21
# 2        AUTOMOTOR - BAJA P/DEST/SIN/DESG/ENVEJ.    2020-01-28
# 3        AUTOMOTOR - BAJA P/DEST/SIN/DESG/ENVEJ.    2020-01-31
# 4        AUTOMOTOR - BAJA P/DEST/SIN/DESG/ENVEJ.    2020-01-14
# ...                                          ...           ...
# 59777    AUTOMOTOR - BAJA P/DEST/SIN/DESG/ENVEJ.    2021-12-28
# 59778    AUTOMOTOR - BAJA P/DEST/SIN/DESG/ENVEJ.    2021-12-09
# 59779  AUTOMOTOR - BAJA C/RECUPERACION DE PIEZAS    2021-12-30
# 59780  AUTOMOTOR - BAJA C/RECUPERACION DE PIEZAS    2021-12-30
# 59781    AUTOMOTOR - BAJA P/DEST/SIN/DESG/ENVEJ.    2021-12-29
#
#       fecha_inscripcion_inicial  registro_seccional_codigo  \
# 0                    1997-12-22                       1014
# 1                    2015-10-02                       1016
# 2                    1999-03-12                       1024
# 3                    2012-10-19                       1043
# 4                    2012-06-13                       1044
# ...                         ...                        ...
# 59777                2007-10-01                       2045
# 59778                2012-10-22                       2045
# 59779                2016-07-07                       4020
# 59780                2017-03-07                      21070
# 59781                2010-11-18                       1103
#
#       registro_seccional_descripcion registro_seccional_provincia  \
# 0                           BRANDSEN                 Buenos Aires
# 1                     CARLOS CASARES                 Buenos Aires
# 2                          CHACABUCO                 Buenos Aires
# 3                     LA PLATA Nº 01                 Buenos Aires
# 4                     LA PLATA Nº 02                 Buenos Aires
# ...                              ...                          ...
# 59777         CAPITAL FEDERAL Nº 045    Ciudad Autónoma de Bs.As.
# 59778         CAPITAL FEDERAL Nº 045    Ciudad Autónoma de Bs.As.
# 59779                VICUÑA MACKENNA                      Córdoba
# 59780                  ROSARIO Nº 18                     Santa Fe
# 59781                    ZARATE Nº 1                 Buenos Aires
#
#       automotor_origen  automotor_anio_modelo automotor_tipo_codigo  \
# 0             Nacional                 1997.0                   NaN
# 1         Protocolo 21                 2015.0                   NaN
# 2             Nacional                 1999.0                   NaN
# 3         Protocolo 21                 2012.0                   NaN
# 4             Nacional                 2012.0                   NaN
# ...                ...                    ...                   ...
# 59777        Importado                 2007.0                   2.0
# 59778        Importado                 2012.0                   2.0
# 59779         Nacional                 2016.0                  12.0
# 59780     Protocolo 21                 2017.0                  80.0
# 59781        Importado                 2010.0                  10.0
#
#       automotor_tipo_descripcion  ... automotor_uso_descripcion  \
# 0                 BERLINA 5 PTAS  ...                   Privado
# 1                        MINIBUS  ...                   Privado
# 2                 BERLINA 4 PTAS  ...                   Privado
# 3                FURGON BLINDADO  ...                   Oficial
# 4            FURGON VIDRIADO C/A  ...                   Privado
# ...                          ...  ...                       ...
# 59777               SEDAN 4 PTAS  ...                   Privado
# 59778            SEDAN 4 PUERTAS  ...                   Privado
# 59779            SEDAN 4 PUERTAS  ...                   Privado
# 59780      PICK-UP CABINA SIMPLE  ...                   Privado
# 59781               TODO TERRENO  ...                   Privado
#
#       titular_tipo_persona titular_domicilio_localidad  \
# 0                   Física          JEPPENER- BRANDSEN
# 1                   Física              CARLOS CASARES
# 2                   Física                   CHACABUCO
# 3                 Jurídica                    LA PLATA
# 4                   Física                      ABASTO
# ...                    ...                         ...
# 59777             Jurídica         C.AUTONOMA DE BS.AS
# 59778             Jurídica         C.AUTONOMA DE BS.AS
# 59779               Física                ADELIA MARÍA
# 59780             Jurídica                     ROSARIO
# 59781               Física                        LIMA
#
#       titular_domicilio_provincia   titular_genero titular_anio_nacimiento  \
# 0                    BUENOS AIRES  No identificado                  1976.0
# 1                    BUENOS AIRES  No identificado                  1967.0
# 2                    BUENOS AIRES         Femenino                  1991.0
# 3                    BUENOS AIRES        No aplica                  1906.0
# 4                    BUENOS AIRES        Masculino                  1974.0
# ...                           ...              ...                     ...
# 59777         C.AUTONOMA DE BS.AS        No aplica                  1979.0
# 59778         C.AUTONOMA DE BS.AS        No aplica                  1947.0
# 59779                     CORDOBA        Masculino                  1988.0
# 59780                    SANTA FE        No aplica                  1991.0
# 59781                BUENOS AIRES        Masculino                  1982.0
#
#       titular_pais_nacimiento titular_porcentaje_titularidad  \
# 0                   ARGENTINA                            100
# 1                   ARGENTINA                            100
# 2                   ARGENTINA                            100
# 3                   No aplica                            100
# 4                      BRASIL                             50
# ...                       ...                            ...
# 59777               No aplica                            100
# 59778               No aplica                            100
# 59779               ARGENTINA                            100
# 59780               No aplica                            100
# 59781               ARGENTINA                            100
#
#       titular_domicilio_provincia_id titular_pais_nacimiento_id
# 0                                6.0                        ARG
# 1                                6.0                        ARG
# 2                                6.0                        ARG
# 3                                6.0                        NaN
# 4                                6.0                        BRA
# ...                              ...                        ...
# 59777                            2.0                        NaN
# 59778                            2.0                        NaN
# 59779                           14.0                        ARG
# 59780                           82.0                        NaN
# 59781                            6.0                        ARG
#
# [59782 rows x 25 columns]

# %%
#Comprobando datos Nan, evidenciamos que la mayor parte de incompletos pertenecen a Nacionalidad del titular ("titular_pais_nacimiento_id")
import missingno as msno
# %matplotlib inline
msno.matrix(dataFrame)

# %%
dataFrame.head()
# Out:
#                                 tramite_tipo tramite_fecha  \
# 0    AUTOMOTOR - BAJA P/DEST/SIN/DESG/ENVEJ.    2020-01-22
# 1  AUTOMOTOR - BAJA C/RECUPERACION DE PIEZAS    2020-01-21
# 2    AUTOMOTOR - BAJA P/DEST/SIN/DESG/ENVEJ.    2020-01-28
# 3    AUTOMOTOR - BAJA P/DEST/SIN/DESG/ENVEJ.    2020-01-31
# 4    AUTOMOTOR - BAJA P/DEST/SIN/DESG/ENVEJ.    2020-01-14
#
#   fecha_inscripcion_inicial  registro_seccional_codigo  \
# 0                1997-12-22                       1014
# 1                2015-10-02                       1016
# 2                1999-03-12                       1024
# 3                2012-10-19                       1043
# 4                2012-06-13                       1044
#
#   registro_seccional_descripcion registro_seccional_provincia  \
# 0                       BRANDSEN                 Buenos Aires
# 1                 CARLOS CASARES                 Buenos Aires
# 2                      CHACABUCO                 Buenos Aires
# 3                 LA PLATA Nº 01                 Buenos Aires
# 4                 LA PLATA Nº 02                 Buenos Aires
#
#   automotor_origen  automotor_anio_modelo automotor_tipo_codigo  \
# 0         Nacional                 1997.0                   NaN
# 1     Protocolo 21                 2015.0                   NaN
# 2         Nacional                 1999.0                   NaN
# 3     Protocolo 21                 2012.0                   NaN
# 4         Nacional                 2012.0                   NaN
#
#   automotor_tipo_descripcion  ... automotor_uso_descripcion  \
# 0             BERLINA 5 PTAS  ...                   Privado
# 1                    MINIBUS  ...                   Privado
# 2             BERLINA 4 PTAS  ...                   Privado
# 3            FURGON BLINDADO  ...                   Oficial
# 4        FURGON VIDRIADO C/A  ...                   Privado
#
#   titular_tipo_persona titular_domicilio_localidad  \
# 0               Física          JEPPENER- BRANDSEN
# 1               Física              CARLOS CASARES
# 2               Física                   CHACABUCO
# 3             Jurídica                    LA PLATA
# 4               Física                      ABASTO
#
#   titular_domicilio_provincia   titular_genero titular_anio_nacimiento  \
# 0                BUENOS AIRES  No identificado                  1976.0
# 1                BUENOS AIRES  No identificado                  1967.0
# 2                BUENOS AIRES         Femenino                  1991.0
# 3                BUENOS AIRES        No aplica                  1906.0
# 4                BUENOS AIRES        Masculino                  1974.0
#
#   titular_pais_nacimiento titular_porcentaje_titularidad  \
# 0               ARGENTINA                            100
# 1               ARGENTINA                            100
# 2               ARGENTINA                            100
# 3               No aplica                            100
# 4                  BRASIL                             50
#
#   titular_domicilio_provincia_id titular_pais_nacimiento_id
# 0                            6.0                        ARG
# 1                            6.0                        ARG
# 2                            6.0                        ARG
# 3                            6.0                        NaN
# 4                            6.0                        BRA
#
# [5 rows x 25 columns]

# %%
dataFrame.describe()
# Out:
#        registro_seccional_codigo  automotor_anio_modelo  automotor_uso_codigo  \
# count               59782.000000           59379.000000          59780.000000
# mean                 6765.665150            2005.679651              1.019689
# std                  7402.305442              76.167787              0.479001
# min                  1001.000000              20.000000              0.000000
# 25%                  1205.000000            2006.000000              1.000000
# 50%                  2071.000000            2011.000000              1.000000
# 75%                 13016.000000            2014.000000              1.000000
# max                 24008.000000            2022.000000              9.000000
#
#        titular_anio_nacimiento  titular_porcentaje_titularidad  \
# count             59727.000000                    59782.000000
# mean               1976.621645                       97.204543
# std                  24.309747                       11.563943
# min                1852.000000                        1.000000
# 25%                1966.000000                      100.000000
# 50%                1978.000000                      100.000000
# 75%                1989.000000                      100.000000
# max                6198.000000                      100.000000
#
#        titular_domicilio_provincia_id
# count                    59775.000000
# mean                        25.889118
# std                         28.944095
# min                          2.000000
# 25%                          6.000000
# 50%                          6.000000
# 75%                         50.000000
# max                         94.000000
